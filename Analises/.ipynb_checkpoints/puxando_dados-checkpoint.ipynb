# %%
# !jt -t monokai -cursc x -cursw 1 -fs 10 -lineh 100

# %%
import pandas as pd
import requests
import datetime
from datetime import timedelta

# %%
import os
os.chdir (r"C:\Users\leovibroz\Documents\Projetos\covid")

# %% [markdown]
# # Consumindo dados

# %% [markdown]
# ## Ignorar

# %%
def change_date(datestr):
  try:
    return datetime.datetime.strptime(datestr[0:10].strip(),"%m/%d/%Y")
  except Exception as e:
    try:
      return datetime.datetime.strptime(datestr[0:8].strip(),"%m/%d/%y")
    except Exception as e:
      try:
        return datetime.datetime.strptime(datestr[0:10].strip(),"%m/%d/%y")
      except Exception as e:
        try:
          return datetime.datetime.strptime(datestr[0:8].strip(),"%m/%d/%Y")
        except Exception as e:
          try:
            return datetime.datetime.strptime(datestr[0:10].strip(),"%Y-%m-%d")
          except Exception as e:
            try:
              return datetime.datetime.strptime(datestr[0:7].strip(),"%m/%d/%y")
            except Exception as e:
              print(e)
              return ('erro')

# %%
a = pd.DataFrame(columns = ['Last_Update','new'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-516c74d4ad73> in <module>
# ----> 1 a = pd.DataFrame(columns = ['Last_Update','new'])
#
# NameError: name 'pd' is not defined

# %%
a['Last_Update'] = df['Last_Update']

# %%
a['new'] = df['Last_Update'].apply(lambda x: change_date(x))

# %% [markdown]
# ## Comecando download

# %%
df = pd.read_csv(r"C:\Users\leovibroz\Documents\Projetos\covid\Analises\casos_covid19.csv"
                      )

# %%
df['Current_Date'] =df['Current_Date'].apply(lambda x: datetime.datetime.strptime(str(x)[0:10],"%Y-%m-%d"))

# %%
scan = True
cur_date = datetime.datetime.strptime(str(df.Current_Date.max() )[0:10],"%Y-%m-%d")

# %%
#scan = True
#df=pd.DataFrame()
#url = '''https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/''' + begin_date.strftime("%m-%d-%Y")+'''.csv'''
#df = pd.read_csv(url)
#df['Current_Date'] = begin_date
#df.columns = ['Province_State','Country_Region','Last_Update','Confirmed','Deaths','Recovered','Current_Date']
#cur_date = begin_date

# %%
while scan == True:
    cur_date = cur_date +  timedelta(days = 1)
    url = '''https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/''' + cur_date.strftime("%m-%d-%Y")+'''.csv'''
    print(url)
    try:
        df_ap = pd.DataFrame(columns = df.columns)
        read = pd.read_csv(url)
        if cur_date < datetime.datetime.strptime('22/03/20',"%d/%m/%y"):
            df_ap['Province_State'] = read['Province/State']
            df_ap['Country_Region'] = read ['Country/Region']
            df_ap['Last_Update']= read ['Last Update']
            df_ap['Current_Date'] = cur_date
            df_ap['Confirmed']= read ['Confirmed']
            df_ap['Deaths']= read['Deaths']
            df_ap['Recovered']= read ['Recovered']
        else:
            df_ap['Province_State'] = read['Province_State']
            df_ap['Country_Region'] = read ['Country_Region']
            df_ap['Last_Update']= read ['Last_Update']
            df_ap['Current_Date'] = cur_date
            df_ap['Confirmed']= read ['Confirmed']
            df_ap['Deaths']= read['Deaths']
            df_ap['Recovered']= read ['Recovered']
        print(pd.read_csv(url).columns)
    except Exception as e:
        print(e)
        scan = False
        break
    df = pd.concat([df,df_ap],axis = 0)

df = df.reset_index(drop = True)
# Out:
# https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-23-2020.csv
# Index(['FIPS', 'Admin2', 'Province_State', 'Country_Region', 'Last_Update',
#        'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'Combined_Key'],
#       dtype='object')
# https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-24-2020.csv
# Index(['FIPS', 'Admin2', 'Province_State', 'Country_Region', 'Last_Update',
#        'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'Combined_Key'],
#       dtype='object')
# https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-25-2020.csv
# Index(['FIPS', 'Admin2', 'Province_State', 'Country_Region', 'Last_Update',
#        'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'Combined_Key'],
#       dtype='object')
# https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-26-2020.csv
# Index(['FIPS', 'Admin2', 'Province_State', 'Country_Region', 'Last_Update',
#        'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'Combined_Key'],
#       dtype='object')
# https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-27-2020.csv
# Index(['FIPS', 'Admin2', 'Province_State', 'Country_Region', 'Last_Update',
#        'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'Combined_Key'],
#       dtype='object')
# https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-28-2020.csv
# Index(['FIPS', 'Admin2', 'Province_State', 'Country_Region', 'Last_Update',
#        'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'Combined_Key'],
#       dtype='object')
# https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-29-2020.csv
# Index(['FIPS', 'Admin2', 'Province_State', 'Country_Region', 'Last_Update',
#        'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'Combined_Key', 'Incidence_Rate', 'Case-Fatality_Ratio'],
#       dtype='object')
# https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-30-2020.csv
# HTTP Error 404: Not Found

# %%
df['Country_Region'].unique()
# Out:
# array(['China', 'Hong Kong', 'Macau', 'Taiwan', 'US', 'Japan', 'Thailand',
#        'South Korea', 'Singapore', 'Philippines', 'Malaysia', 'Vietnam',
#        'Australia', 'Mexico', 'Brazil', 'Colombia', 'France', 'Nepal',
#        'Canada', 'Cambodia', 'Sri Lanka', 'Ivory Coast', 'Germany',
#        'Finland', 'United Arab Emirates', 'India', 'Italy', 'UK',
#        'Russia', 'Sweden', 'Spain', 'Belgium', 'Others', 'Egypt', 'Iran',
#        'Israel', 'Lebanon', 'Iraq', 'Oman', 'Afghanistan', 'Bahrain',
#        'Kuwait', 'Austria', 'Algeria', 'Croatia', 'Switzerland',
#        'Pakistan', 'Georgia', 'Greece', 'North Macedonia', 'Norway',
#        'Romania', 'Denmark', 'Estonia', 'Netherlands', 'San Marino',
#        ' Azerbaijan', 'Belarus', 'Iceland', 'Lithuania', 'New Zealand',
#        'Nigeria', 'North Ireland', 'Ireland', 'Luxembourg', 'Monaco',
#        'Qatar', 'Ecuador', 'Azerbaijan', 'Czech Republic', 'Armenia',
#        'Dominican Republic', 'Indonesia', 'Portugal', 'Andorra', 'Latvia',
#        'Morocco', 'Saudi Arabia', 'Senegal', 'Argentina', 'Chile',
#        'Jordan', 'Ukraine', 'Saint Barthelemy', 'Hungary',
#        'Faroe Islands', 'Gibraltar', 'Liechtenstein', 'Poland', 'Tunisia',
#        'Palestine', 'Bosnia and Herzegovina', 'Slovenia', 'South Africa',
#        'Bhutan', 'Cameroon', 'Costa Rica', 'Peru', 'Serbia', 'Slovakia',
#        'Togo', 'Vatican City', 'French Guiana', 'Malta', 'Martinique',
#        'Republic of Ireland', 'Bulgaria', 'Maldives', 'Bangladesh',
#        'Moldova', 'Paraguay', 'Albania', 'Cyprus', 'St. Martin', 'Brunei',
#        'Iran (Islamic Republic of)', 'Republic of Korea', 'Hong Kong SAR',
#        'Taipei and environs', 'Viet Nam',
#        'occupied Palestinian territory', 'Macao SAR',
#        'Russian Federation', 'Republic of Moldova', 'Saint Martin',
#        'Burkina Faso', 'Channel Islands', 'Holy See', 'Mongolia',
#        'Panama', 'Korea, South', 'Cruise Ship', 'United Kingdom',
#        'Czechia', 'Taiwan*', 'Bolivia', 'Honduras', 'Congo (Kinshasa)',
#        "Cote d'Ivoire", 'Jamaica', 'Reunion', 'Turkey', 'Cuba', 'Guyana',
#        'Kazakhstan', 'Cayman Islands', 'Guadeloupe', 'Ethiopia', 'Sudan',
#        'Guinea', 'Antigua and Barbuda', 'Aruba', 'Kenya', 'Uruguay',
#        'Ghana', 'Jersey', 'Namibia', 'Seychelles', 'Trinidad and Tobago',
#        'Venezuela', 'Curacao', 'Eswatini', 'Gabon', 'Guatemala',
#        'Guernsey', 'Mauritania', 'Rwanda', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'Suriname', 'Kosovo',
#        'Central African Republic', 'Congo (Brazzaville)',
#        'Equatorial Guinea', 'Uzbekistan', 'Guam', 'Puerto Rico', 'Benin',
#        'Greenland', 'Liberia', 'Mayotte', 'Republic of the Congo',
#        'Somalia', 'Tanzania', 'The Bahamas', 'Barbados', 'Montenegro',
#        'The Gambia', 'Kyrgyzstan', 'Mauritius', 'Zambia', 'Djibouti',
#        'Gambia, The', 'Bahamas, The', 'Chad', 'El Salvador', 'Fiji',
#        'Nicaragua', 'Madagascar', 'Haiti', 'Angola', 'Cabo Verde',
#        'Niger', 'Papua New Guinea', 'Zimbabwe', 'Cape Verde',
#        'East Timor', 'Eritrea', 'Uganda', 'Bahamas', 'Dominica', 'Gambia',
#        'Grenada', 'Mozambique', 'Syria', 'Timor-Leste', 'Belize', 'Laos',
#        'Libya', 'Diamond Princess', 'Guinea-Bissau', 'Mali',
#        'Saint Kitts and Nevis', 'West Bank and Gaza', 'Burma',
#        'MS Zaandam', 'Botswana', 'Burundi', 'Sierra Leone', 'Malawi',
#        'South Sudan', 'Western Sahara', 'Sao Tome and Principe', 'Yemen',
#        'Comoros', 'Tajikistan', 'Lesotho'], dtype=object)

# %%
# Nao utilizo mais
#df['Last_Update'] = df['Last_Update'].apply(lambda x: change_date(x))
df[df['Country_Region'] == 'United Kingdom']
# Out:
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1               Province_State  \
# 4743          4743          4743            4743                           UK
# 4896          4896          4896            4896              Channel Islands
# 4923          4923          4923            4923                    Gibraltar
# 4960          4960          4960            4960                           UK
# 5118          5118          5118            5118              Channel Islands
# 5144          5144          5144            5144                    Gibraltar
# 5196          5196          5196            5196              Channel Islands
# 5239          5239          5239            5239               United Kingdom
# 5289          5289          5289            5289                    Gibraltar
# 5394          5394          5394            5394               United Kingdom
# 5593          5593          5593            5593              Channel Islands
# 5628          5628          5628            5628                    Gibraltar
# 5644          5644          5644            5644               United Kingdom
# 5833          5833          5833            5833              Channel Islands
# 5885          5885          5885            5885                    Gibraltar
# 5898          5898          5898            5898               United Kingdom
# 6088          6088          6088            6088              Channel Islands
# 6157          6157          6157            6157               Cayman Islands
# 6158          6158          6158            6158                    Gibraltar
# 6170          6170          6170            6170               United Kingdom
# 6374          6374          6374            6374              Channel Islands
# 6394          6394          6394            6394                    Gibraltar
# 6431          6431          6431            6431               Cayman Islands
# 6446          6446          6446            6446               United Kingdom
# 6644          6644          6644            6644                    Gibraltar
# 6656          6656          6656            6656              Channel Islands
# 6709          6709          6709            6709               Cayman Islands
# 6710          6710          6710            6710                   Montserrat
# 6731          6731          6731            6731               United Kingdom
# 6929          6929          6929            6929              Channel Islands
# ...            ...           ...             ...                          ...
# 153723           0             0               0               Cayman Islands
# 153726           0             0               0              Channel Islands
# 153742           0             0               0  Falkland Islands (Malvinas)
# 153750           0             0               0                    Gibraltar
# 153773           0             0               0                  Isle of Man
# 153803           0             0               0                   Montserrat
# 153883           0             0               0     Turks and Caicos Islands
# 154070           0             0               0                            0
# 6158     2020-03-16 2020-03-11                5
# 6170     2020-03-17 2020-03-11                6
# 6374     2020-03-17 2020-03-11                6
# 6394     2020-03-17 2020-03-11                6
# 6431     2020-03-17 2020-03-11                6
# 6446     2020-03-18 2020-03-11                7
# 6644     2020-03-18 2020-03-11                7
# 6656     2020-03-18 2020-03-11                7
# 6709     2020-03-18 2020-03-11                7
# 6710     2020-03-18 2020-03-11                7
# 6731     2020-03-19 2020-03-11                8
# 6929     2020-03-19 2020-03-11                8
# ...             ...        ...              ...
# 153723   2020-05-27 2020-03-11               77
# 153726   2020-05-27 2020-03-11               77
# 153742   2020-05-27 2020-03-11               77
# 153750   2020-05-27 2020-03-11               77
# 153773   2020-05-27 2020-03-11               77
# 153803   2020-05-27 2020-03-11               77
# 153883   2020-05-27 2020-03-11               77
# 154070   2020-05-27 2020-03-11               77
# 157109   2020-05-28 2020-03-11               78
# 157136   2020-05-28 2020-03-11               78
# 157144   2020-05-28 2020-03-11               78
# 157161   2020-05-28 2020-03-11               78
# 157165   2020-05-28 2020-03-11               78
# 157187   2020-05-28 2020-03-11               78
# 157198   2020-05-28 2020-03-11               78
# 157232   2020-05-28 2020-03-11               78
# 157280   2020-05-28 2020-03-11               78
# 157395   2020-05-28 2020-03-11               78
# 157588   2020-05-28 2020-03-11               78
# 160630   2020-05-29 2020-03-11               79
# 160657   2020-05-29 2020-03-11               79
# 160665   2020-05-29 2020-03-11               79
# 160682   2020-05-29 2020-03-11               79
# 160686   2020-05-29 2020-03-11               79
# 160708   2020-05-29 2020-03-11               79
# 160719   2020-05-29 2020-03-11               79
# 160754   2020-05-29 2020-03-11               79
# 160802   2020-05-29 2020-03-11               79
# 160917   2020-05-29 2020-03-11               79
# 161110   2020-05-29 2020-03-11               79
#
# [776 rows x 12 columns]

# %%
df['Country_Region'] = df['Country_Region'].apply(lambda x: 'China' if( x == 'Mainland China') else x)

# %%
df = df.fillna(0)

# %%
new_names = {
        'United States of America':'US',
        'Russian Federation':'Russia',
        'United Kingdom':'UK'
}

# %%
df['Country_Region'] = df.apply(lambda x: new_names[x['Country_Region']] if  x['Country_Region'] in new_names  else x['Country_Region'],axis = 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4380             try:
# -> 4381                 return libindex.get_value_box(s, key)
#    4382             except IndexError:
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_box()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-127-976c08b5d3c0> in <module>
# ----> 1 df['Country_Region'] = df.apply(lambda x: new_names[x['country_region']] if  x['country_region'] in new_names  else x['country_region'],axis = 1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     255
#     256         # compute the result using the series generator
# --> 257         self.apply_series_generator()
#     258
#     259         # wrap results
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     284             try:
#     285                 for i, v in enumerate(series_gen):
# --> 286                     results[i] = self.f(v)
#     287                     keys.append(v.name)
#     288             except Exception as e:
#
# <ipython-input-127-976c08b5d3c0> in <lambda>(x)
# ----> 1 df['Country_Region'] = df.apply(lambda x: new_names[x['country_region']] if  x['country_region'] in new_names  else x['country_region'],axis = 1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4387                     raise InvalidIndexError(key)
#    4388                 else:
# -> 4389                     raise e1
#    4390             except Exception:  # pragma: no cover
#    4391                 raise e1
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#    4377             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('country_region', 'occurred at index 0')

# %% [markdown]
# # Data da Primeira infeccao

# %%
df = df.drop(['prim_infec','dias_desde_prim'],axis = 1)

# %%
prim_infec = df[df['Confirmed'] > 0].groupby(['Country_Region']).agg({'Current_Date':'min'})

# %%
prim_infec.columns = ['prim_infec']

# %%
df = df.reset_index(drop = True)

# %%
df = df.merge(prim_infec,how='left',on='Country_Region')

# %%
df['dias_desde_prim'] = df.apply(lambda row: (row['Current_Date'] - row['prim_infec']).days,axis = 1)

# %%
df = df.drop_duplicates()

# %%
# 161102      0.0       24.0   2020-05-29 2020-03-22               68
# 161103     13.0      202.0   2020-05-29 2020-03-06               84
# 161104      8.0      108.0   2020-05-29 2020-03-14               76
# 161105     48.0      946.0   2020-05-29 2020-03-04               86
# 161106   4489.0   125963.0   2020-05-29 2020-03-11               79
# 161107      0.0       72.0   2020-05-29 2020-03-21               69
# 161108    679.0     8934.0   2020-05-29 2020-03-03               87
# 161109    260.0    17097.0   2020-05-29 2020-01-29              121
# 161110  38161.0        0.0   2020-05-29 2020-03-11               79
# 161111     22.0      680.0   2020-05-29 2020-03-14               76
# 161112     14.0     2728.0   2020-05-29 2020-03-15               75
# 161113     14.0      302.0   2020-05-29 2020-03-14               76
# 161114      0.0      279.0   2020-05-29 2020-01-23              127
# 161115      3.0      368.0   2020-05-29 2020-03-26               64
# 161116      1.0        6.0   2020-05-29 2020-04-05               54
# 161117     65.0       11.0   2020-05-29 2020-04-10               49
# 161118      7.0      779.0   2020-05-29 2020-03-18               72
# 161119      4.0       28.0   2020-05-29 2020-03-20               70
#
# [157052 rows x 9 columns]

# %% [markdown]
# # Testing

# %%
url = '''https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/testing/covid-testing-all-observations.csv'''
df_testing = pd.read_csv(url)

# %%
df_testing.columns = df_testing.columns.str.lower()

# %%
df_testing['date'] =df_testing['date'].apply(lambda x: datetime.datetime.strptime(str(x)[0:10],"%Y-%m-%d"))

# %%
df_testing['entity_type'] = df_testing['entity'].apply(lambda x: x.split(' - ')[1])
df_testing['country'] = df_testing['entity'].apply(lambda x: x.split(' - ')[0].strip())

# %%
df_testing
# Out:
#                            entity iso code       date  \
# 0     Argentina - tests performed      ARG 2020-04-08
# 1     Argentina - tests performed      ARG 2020-04-09
# 2     Argentina - tests performed      ARG 2020-04-10
# 3     Argentina - tests performed      ARG 2020-04-11
# 4     Argentina - tests performed      ARG 2020-04-12
# 5     Argentina - tests performed      ARG 2020-04-13
# 6     Argentina - tests performed      ARG 2020-04-14
# 7     Argentina - tests performed      ARG 2020-04-15
# 8     Argentina - tests performed      ARG 2020-04-16
# 9     Argentina - tests performed      ARG 2020-04-17
# 10    Argentina - tests performed      ARG 2020-04-18
# 11    Argentina - tests performed      ARG 2020-04-19
# 12    Argentina - tests performed      ARG 2020-04-20
# 13    Argentina - tests performed      ARG 2020-04-21
# 14    Argentina - tests performed      ARG 2020-04-22
# 15    Argentina - tests performed      ARG 2020-04-23
# 16    Argentina - tests performed      ARG 2020-04-24
# 17    Argentina - tests performed      ARG 2020-04-25
# 18    Argentina - tests performed      ARG 2020-04-26
# 19    Argentina - tests performed      ARG 2020-04-27
# 20    Argentina - tests performed      ARG 2020-04-28
# 21    Argentina - tests performed      ARG 2020-04-29
# 22    Argentina - tests performed      ARG 2020-04-30
# 23    Argentina - tests performed      ARG 2020-05-01
# 24    Argentina - tests performed      ARG 2020-05-02
# 25    Argentina - tests performed      ARG 2020-05-03
# 26    Argentina - tests performed      ARG 2020-05-04
# 27    Argentina - tests performed      ARG 2020-05-05
# 28    Argentina - tests performed      ARG 2020-05-06
# 29    Argentina - tests performed      ARG 2020-05-07
# 10                         1845.0                                     0.041
# 11                         1974.0                                     0.044
# 12                         2116.0                                     0.047
# 13                         1972.0                                     0.044
# 14                         2122.0                                     0.047
# 15                         2190.0                                     0.048
# 16                         2286.0                                     0.051
# 17                         2352.0                                     0.052
# 18                         2456.0                                     0.054
# 19                         2476.0                                     0.055
# 20                         2427.0                                     0.054
# 21                         2404.0                                     0.053
# 22                         2414.0                                     0.053
# 23                         2411.0                                     0.053
# 24                         2351.0                                     0.052
# 25                         2273.0                                     0.050
# 26                         2289.0                                     0.051
# 27                         2303.0                                     0.051
# 28                         2322.0                                     0.051
# 29                         2359.0                                     0.052
# ...                           ...                                       ...
# 6504                       4080.0                                     0.042
# 6505                       4407.0                                     0.045
# 6506                       4957.0                                     0.051
# 6507                       5415.0                                     0.056
# 6508                       6086.0                                     0.063
# 6509                       6757.0                                     0.069
# 6510                       6960.0                                     0.072
# 6511                       6636.0                                     0.068
# 6512                       7291.0                                     0.075
# 6513                       7946.0                                     0.082
# 6514                       7084.0                                     0.073
# 6515                       6003.0                                     0.062
# 6516                       8187.0                                     0.084
# 6517                      10906.0                                     0.112
# 6518                          NaN                                       NaN
# 6519                          NaN                                       NaN
# 6520                          NaN                                       NaN
# 6521                          NaN                                       NaN
# 6522                          NaN                                       NaN
# 6523                          NaN                                       NaN
# 6524                          NaN                                       NaN
# 6525                        483.0                                     0.032
# 6526                        451.0                                     0.030
# 6527                        380.0                                     0.026
# 6528                        383.0                                     0.026
# 6529                        385.0                                     0.026
# 6530                        358.0                                     0.024
# 6531                        445.0                                     0.030
# 6532                        490.0                                     0.033
# 6533                        541.0                                     0.036
#
#           entity_type    country
# 0     tests performed  Argentina
# 1     tests performed  Argentina
# 2     tests performed  Argentina
# 3     tests performed  Argentina
# 4     tests performed  Argentina
# 5     tests performed  Argentina
# 6     tests performed  Argentina
# 7     tests performed  Argentina
# 8     tests performed  Argentina
# 9     tests performed  Argentina
# 10    tests performed  Argentina
# 11    tests performed  Argentina
# 12    tests performed  Argentina
# 13    tests performed  Argentina
# 14    tests performed  Argentina
# 15    tests performed  Argentina
# 16    tests performed  Argentina
# 17    tests performed  Argentina
# 18    tests performed  Argentina
# 19    tests performed  Argentina
# 20    tests performed  Argentina
# 21    tests performed  Argentina
# 22    tests performed  Argentina
# 23    tests performed  Argentina
# 24    tests performed  Argentina
# 25    tests performed  Argentina
# 26    tests performed  Argentina
# 27    tests performed  Argentina
# 28    tests performed  Argentina
# 29    tests performed  Argentina
# ...               ...        ...
# 6504    units unclear    Vietnam
# 6505    units unclear    Vietnam
# 6506    units unclear    Vietnam
# 6507    units unclear    Vietnam
# 6508    units unclear    Vietnam
# 6509    units unclear    Vietnam
# 6510    units unclear    Vietnam
# 6511    units unclear    Vietnam
# 6512    units unclear    Vietnam
# 6513    units unclear    Vietnam
# 6514    units unclear    Vietnam
# 6515    units unclear    Vietnam
# 6516    units unclear    Vietnam
# 6517    units unclear    Vietnam
# 6518  tests performed   Zimbabwe
# 6519  tests performed   Zimbabwe
# 6520  tests performed   Zimbabwe
# 6521  tests performed   Zimbabwe
# 6522  tests performed   Zimbabwe
# 6523  tests performed   Zimbabwe
# 6524  tests performed   Zimbabwe
# 6525  tests performed   Zimbabwe
# 6526  tests performed   Zimbabwe
# 6527  tests performed   Zimbabwe
# 6528  tests performed   Zimbabwe
# 6529  tests performed   Zimbabwe
# 6530  tests performed   Zimbabwe
# 6531  tests performed   Zimbabwe
# 6532  tests performed   Zimbabwe
# 6533  tests performed   Zimbabwe
#
# [6534 rows x 14 columns]

# %%
df_testing_mg = df_testing[['date','country','entity_type','iso code'
                            ,'cumulative total','daily change in cumulative total']].fillna(0)

# %%
df_testing_mg.columns = ['Current_Date','Country_Region','entity_type','iso_code'
                            ,'cumulative_total','daily_change']

# %% [markdown]
# # Join

# %%
df.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0.1 Province_State Country_Region      Last_Update  \
# 0           0             0          Anhui          China  1/22/2020 17:00
# 1           1             1        Beijing          China  1/22/2020 17:00
# 2           2             2      Chongqing          China  1/22/2020 17:00
# 3           3             3         Fujian          China  1/22/2020 17:00
# 4           4             4          Gansu          China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered Current_Date prim_infec  dias_desde_prim
# 0        1.0     0.0        0.0   2020-01-22 2020-01-22                0
# 1       14.0     0.0        0.0   2020-01-22 2020-01-22                0
# 2        6.0     0.0        0.0   2020-01-22 2020-01-22                0
# 3        1.0     0.0        0.0   2020-01-22 2020-01-22                0
# 4        0.0     0.0        0.0   2020-01-22 2020-01-22                0

# %%
df_testing_mg.head(5)
# Out:
#   Current_Date Country_Region      entity_type iso_code  cumulative_total  \
# 0   2020-04-08      Argentina  tests performed      ARG           13330.0
# 1   2020-04-09      Argentina  tests performed      ARG           14850.0
# 2   2020-04-10      Argentina  tests performed      ARG           16379.0
# 3   2020-04-11      Argentina  tests performed      ARG           18027.0
# 4   2020-04-12      Argentina  tests performed      ARG               0.0
#
#    daily_change
# 0           0.0
# 1        1520.0
# 2        1529.0
# 3        1648.0
# 4           0.0

# %%
df_testing_mg[['entity_type','cumulative_total','daily_change']]
# Out:
#           entity_type  cumulative_total  daily_change
# 0     tests performed           13330.0           0.0
# 1     tests performed           14850.0        1520.0
# 2     tests performed           16379.0        1529.0
# 3     tests performed           18027.0        1648.0
# 4     tests performed               0.0           0.0
# 5     tests performed           19758.0           0.0
# 6     tests performed           22805.0        3047.0
# 7     tests performed           24374.0        1569.0
# 8     tests performed           26457.0        2083.0
# 9     tests performed           28650.0        2193.0
# 10    tests performed           30942.0        2292.0
# 11    tests performed           32712.0        1770.0
# 12    tests performed           34568.0        1856.0
# 13    tests performed           36611.0        2043.0
# 14    tests performed           39228.0        2617.0
# 15    tests performed           41786.0        2558.0
# 16    tests performed           44654.0        2868.0
# 17    tests performed           47406.0        2752.0
# 18    tests performed           49905.0        2499.0
# 19    tests performed           51900.0        1995.0
# 20    tests performed           53600.0        1700.0
# 21    tests performed           56058.0        2458.0
# 22    tests performed           58685.0        2627.0
# 23    tests performed           61530.0        2845.0
# 24    tests performed           63866.0        2336.0
# 25    tests performed           65813.0        1947.0
# 26    tests performed           67920.0        2107.0
# 27    tests performed           69718.0        1798.0
# 28    tests performed           72315.0        2597.0
# 29    tests performed           75198.0        2883.0
# ...               ...               ...           ...
# 6504    units unclear               0.0           0.0
# 6505    units unclear               0.0           0.0
# 6506    units unclear               0.0           0.0
# 6507    units unclear          163377.0           0.0
# 6508    units unclear               0.0           0.0
# 6509    units unclear          180067.0           0.0
# 6510    units unclear               0.0           0.0
# 6511    units unclear          189253.0           0.0
# 6512    units unclear               0.0           0.0
# 6513    units unclear          212142.0           0.0
# 6514    units unclear          212965.0         823.0
# 6515    units unclear          213743.0         778.0
# 6516    units unclear               0.0           0.0
# 6517    units unclear          261004.0           0.0
# 6518  tests performed            7808.0           0.0
# 6519  tests performed            8141.0         333.0
# 6520  tests performed            8741.0         600.0
# 6521  tests performed            9593.0         852.0
# 6522  tests performed            9872.0         279.0
# 6523  tests performed           10598.0         726.0
# 6524  tests performed           11058.0         460.0
# 6525  tests performed           11191.0         133.0
# 6526  tests performed               0.0           0.0
# 6527  tests performed           11401.0           0.0
# 6528  tests performed           12275.0         874.0
# 6529  tests performed           12564.0         289.0
# 6530  tests performed           13104.0         540.0
# 6531  tests performed           14175.0        1071.0
# 6532  tests performed           14618.0         443.0
# 6533  tests performed           15084.0         466.0
#
# [6534 rows x 3 columns]

# %%
df_testing_mg.to_csv('Analises/testing.csv')

# %%
df_testing

# %%
df_merge = pd.merge(df,df_testing_mg[['Current_Date','Country_Region','entity_type','cumulative_total','daily_change']]
                    ,how = 'left',on=['Current_Date','Country_Region'])

# %%
# Arrumar paises

# %%
df_merge[df_merge['Country_Region'] == 'Brazil']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-5a56b3b10ad1> in <module>
# ----> 1 df_merge[df_merge['Country_Region'] == 'Brazil']
#
# NameError: name 'df_merge' is not defined

# %% [markdown]
# # Populacao

# %%
df_pop = pd.read_csv('Analises/dados_origem/populacao.csv',encoding='ISO-8859-1',delimiter = ';')

# %%
df_pop.columns
# Out:
# Index(['Index', 'Variant', 'Region, subregion, country or area *', 'Notes',
#        'Country code', 'Type', 'Parent code', 'Reference date (as of 1 July)',
#        '0-4', '5-9', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39',
#        '40-44', '45-49', '50-54', '55-59', '60-64', '65-69', '70-74', '75-79',
#        '80-84', '85-89', '90-94', '95-99', '100+'],
#       dtype='object')

# %%
df_pop.columns = ['index', 'variant', 'country_region', 'Notes',
       'country_code', 'type', 'parent_code', 'dt_ref',
       '0-4', '5-9', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39',
       '40-44', '45-49', '50-54', '55-59', '60-64', '65-69', '70-74', '75-79',
       '80-84', '85-89', '90-94', '95-99', '100+']

# %%
df_pop['type'].unique()
# Out:
# array(['World', 'Label/Separator', 'Development Group', 'Special other',
#        'Income Group', 'Region', 'SDG region', 'Subregion',
#        'Country/Area', 'SDG subregion'], dtype=object)

# %%
df_pop_0 = df_pop[df_pop['type'] == 'Country/Area']

# %%
int_col = ['0-4', '5-9', '10-14',
       '15-19', '20-24', '25-29', '30-34', '35-39', '40-44', '45-49', '50-54',
       '55-59', '60-64', '65-69', '70-74', '75-79', '80-84', '85-89', '90-94',
       '95-99', '100+']

# %%
def convert_int(x):
    if type(x) == str:
        return  int(x.strip().replace(' ',''))*1000
    else:
        return x

# %%
for col in int_col:
    df_pop_0[col] = df_pop_0[col].apply(lambda x: convert_int(x))
    df_pop_0[col] = pd.to_numeric(df_pop_0[col])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_pop_0.to_csv('Analises/pop_country.csv')
